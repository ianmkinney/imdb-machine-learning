# %%
import pandas as pd
from sqlalchemy import create_engine
import connection_string

# %%
engine = create_engine(connection_string.connection_string)
con = engine.connect()

# %%
sample_df = pd.read_csv('Sample/sample.csv')
sample_df.drop('Unnamed: 0', axis=1, inplace=True)
sample_df.head()
# Out:
#   imdb_title_id                        title original_title  year  \
# 0     tt0266987                     Spy Game       Spy Game  2001
# 1     tt0414951  The Quiet - Segreti svelati      The Quiet  2005
# 2     tt3315342        Logan - The Wolverine          Logan  2017
# 3     tt0441773                Kung Fu Panda  Kung Fu Panda  2008
# 4     tt2872732                         Lucy           Lucy  2014
#
#   date_published                         genre  duration  \
# 0     2001-12-14       Action, Crime, Thriller       126
# 1     2007-03-20        Crime, Drama, Thriller        96
# 2     2017-03-01         Action, Drama, Sci-Fi       137
# 3     2008-08-29  Animation, Action, Adventure        92
# 4     2014-09-25      Action, Sci-Fi, Thriller        89
#
#                                     country  \
# 0               USA, Germany, Japan, France
# 1                                       USA
# 2                                       USA
# ...

# %%
sample_df['genre'].value_counts()
# Out:
# Drama                           1478
# Comedy                           926
# Comedy, Drama                    455
# Drama, Romance                   400
# Comedy, Romance                  288
#                                 ...
# Adventure, Family, Mystery         1
# Animation, Adventure, Horror       1
# Romance, War, Drama                1
# Animation, Action, Horror          1
# Family, Horror, Mystery            1
# Name: genre, Length: 589, dtype: int64

# %%
sample_df.to_sql('imdb_data', con, if_exists='replace')
