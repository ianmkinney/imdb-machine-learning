# %%
import pandas as pd

# The path to our CSV file
file = "Sample/sample.csv"

# Read our Kickstarter data into pandas
sample_df = pd.read_csv(file)
sample_df.head()
# Out:
#    Unnamed: 0 imdb_title_id                        title    original_title  \
# 0           0     tt0343135  ...E alla fine arriva Polly  Along Came Polly
# 1           1     tt2180411               Into the Woods    Into the Woods
# 2           2     tt2304933               La quinta onda      The 5th Wave
# 3           3     tt1430132      Wolverine - L'immortale     The Wolverine
# 4           4     tt1915581                   Magic Mike        Magic Mike
#
#    year date_published                      genre  duration  country  \
# 0  2004     2004-03-12            Comedy, Romance        90      USA
# 1  2014     2015-04-02   Adventure, Comedy, Drama       125      USA
# 2  2016     2016-02-04  Action, Adventure, Sci-Fi       112  USA, UK
# 3  2013     2013-07-25  Action, Adventure, Sci-Fi       126  USA, UK
# 4  2012     2012-09-21              Comedy, Drama       110      USA
#
#             language  ... females_30age_avg_vote females_30age_votes  \
# ...

# %%
new_df = pd.DataFrame(sample_df.genre.str.split(',').tolist(), index=sample_df.original_title).stack()
new_df
# Out:
# original_title
# Along Came Polly   0       Comedy
#                    1      Romance
# Into the Woods     0    Adventure
#                    1       Comedy
#                    2        Drama
#                           ...
# Bohemian Rhapsody  1        Drama
#                    2        Music
# Begin Again        0       Comedy
#                    1        Drama
#                    2        Music
# Length: 25872, dtype: object

# %%
new_df = new_df.reset_index([0,'original_title'])
new_df
# Out:
#           original_title          0
# 0       Along Came Polly     Comedy
# 1       Along Came Polly    Romance
# 2         Into the Woods  Adventure
# 3         Into the Woods     Comedy
# 4         Into the Woods      Drama
# ...                  ...        ...
# 25867  Bohemian Rhapsody      Drama
# 25868  Bohemian Rhapsody      Music
# 25869        Begin Again     Comedy
# 25870        Begin Again      Drama
# 25871        Begin Again      Music
#
# [25872 rows x 2 columns]

# %%
new_df.columns = ['original_title', 'genre']
new_df
# Out:
#           original_title      genre
# 0       Along Came Polly     Comedy
# 1       Along Came Polly    Romance
# 2         Into the Woods  Adventure
# 3         Into the Woods     Comedy
# 4         Into the Woods      Drama
# ...                  ...        ...
# 25867  Bohemian Rhapsody      Drama
# 25868  Bohemian Rhapsody      Music
# 25869        Begin Again     Comedy
# 25870        Begin Again      Drama
# 25871        Begin Again      Music
#
# [25872 rows x 2 columns]
