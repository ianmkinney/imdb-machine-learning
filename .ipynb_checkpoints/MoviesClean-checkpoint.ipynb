# %%
import pandas as pd
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder
from sklearn.ensemble import RandomForestRegressor

# %%
# The path to our CSV file
file = "Resources/IMDb movies.csv"

# Read our Kickstarter data into pandas
movies_df = pd.read_csv(file)
movies_df.head()
# Out:
# C:\Users\EDDY\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
# The path to our CSV file
file = "Resources/IMDb ratings.csv"

# Read our Kickstarter data into pandas
ratings_df = pd.read_csv(file)
ratings_df.head()
# Out:
#   imdb_title_id  weighted_average_vote  total_votes  mean_vote  median_vote  \
# 0     tt0000009                    5.9          154        5.9          6.0
# 1     tt0000574                    6.1          589        6.3          6.0
# 2     tt0001892                    5.8          188        6.0          6.0
# 3     tt0002101                    5.2          446        5.3          5.0
# 4     tt0002130                    7.0         2237        6.9          7.0
#
#    votes_10  votes_9  votes_8  votes_7  votes_6  ...  females_30age_avg_vote  \
# 0        12        4       10       43       28  ...                     5.7
# 1        57       18       58      137      139  ...                     6.2
# 2         6        6       17       44       52  ...                     5.8
# 3        15        8       16       62       98  ...                     5.5
# 4       210      225      436      641      344  ...                     7.3
#
#    females_30age_votes  females_45age_avg_vote  females_45age_votes  \
# 0                 13.0                     4.5                  4.0
# 1                 23.0                     6.6                 14.0
# 2                  4.0                     6.8                  7.0
# 3                 14.0                     6.1                 21.0
# 4                 82.0                     7.4                 77.0
#
#    top1000_voters_rating  top1000_voters_votes  us_voters_rating  \
# 0                    5.7                  34.0               6.4
# 1                    6.4                  66.0               6.0
# 2                    5.4                  32.0               6.2
# 3                    4.9                  57.0               5.5
# 4                    6.9                 139.0               7.0
#
#    us_voters_votes  non_us_voters_rating  non_us_voters_votes
# 0             51.0                   6.0                 70.0
# 1             96.0                   6.2                331.0
# 2             31.0                   5.9                123.0
# 3            207.0                   4.7                105.0
# 4            488.0                   7.0               1166.0
#
# [5 rows x 49 columns]

# %%
merged_df = pd.merge(movies_df, ratings_df, on='imdb_title_id')
merged_df
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year date_published  \
# 0                          Miss Jerry  1894     1894-10-09
# 1         The Story of the Kelly Gang  1906     1906-12-26
# 2                      Den sorte drøm  1911     1911-08-19
# 3                           Cleopatra  1912     1912-11-13
# 4                           L'Inferno  1911     1911-03-06
# ...                               ...   ...            ...
# 85850                         Le lion  2020     2020-01-29
# 85851  De Beentjes van Sint-Hildegard  2020     2020-02-13
# 85852       Padmavyuhathile Abhimanyu  2019     2019-03-08
# 85853               Sokagin Çocuklari  2019     2019-03-15
# 85854      La vida sense la Sara Amat  2019     2020-02-05
#
#                            genre  duration           country       language  \
# 0                        Romance        45               USA           None
# 1        Biography, Crime, Drama        70         Australia           None
# 2                          Drama        53  Germany, Denmark            NaN
# 3                 Drama, History       100               USA        English
# 4      Adventure, Drama, Fantasy        68             Italy        Italian
# ...                          ...       ...               ...            ...
# 85850                     Comedy        95   France, Belgium         French
# 85851              Comedy, Drama       103       Netherlands  German, Dutch
# 85852                      Drama       130             India      Malayalam
# 85853              Drama, Family        98            Turkey        Turkish
# 85854                      Drama        74             Spain        Catalan
#
#                                   director  ... females_30age_avg_vote  \
# 0                          Alexander Black  ...                    5.7
# 1                             Charles Tait  ...                    6.2
# 2                                Urban Gad  ...                    5.8
# 3                       Charles L. Gaskill  ...                    5.5
# 4      Francesco Bertolini, Adolfo Padovan  ...                    7.3
# ...                                    ...  ...                    ...
# 85850               Ludovic Colbeau-Justin  ...                    5.7
# 85851                      Johan Nijenhuis  ...                    8.0
# 85852                      Vineesh Aaradya  ...                    NaN
# 85853                    Ahmet Faik Akinci  ...                    NaN
# 85854                            Laura Jou  ...                    6.8
#
#       females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0                    13.0                    4.5                 4.0
# 1                    23.0                    6.6                14.0
# 2                     4.0                    6.8                 7.0
# 3                    14.0                    6.1                21.0
# 4                    82.0                    7.4                77.0
# ...                   ...                    ...                 ...
# 85850                11.0                    5.0                 2.0
# 85851                47.0                    7.3                30.0
# 85852                 NaN                    NaN                 NaN
# 85853                 NaN                    7.0                 1.0
# 85854                 4.0                    7.5                 4.0
#
#        top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                        5.7                  34.0              6.4
# 1                        6.4                  66.0              6.0
# 2                        5.4                  32.0              6.2
# 3                        4.9                  57.0              5.5
# 4                        6.9                 139.0              7.0
# ...                      ...                   ...              ...
# 85850                    5.5                  12.0              6.3
# 85851                    7.0                   6.0              6.8
# 85852                    1.0                   1.0              NaN
# 85853                    4.0                   3.0              1.7
# 85854                    7.0                   4.0              6.7
#
#       us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0                51.0                  6.0                 70.0
# 1                96.0                  6.2                331.0
# 2                31.0                  5.9                123.0
# 3               207.0                  4.7                105.0
# 4               488.0                  7.0               1166.0
# ...               ...                  ...                  ...
# 85850            22.0                  5.3                214.0
# 85851            13.0                  7.7                388.0
# 85852             NaN                  2.0                  2.0
# 85853             5.0                  5.8                  5.0
# 85854            13.0                  6.7                 60.0
#
# [85855 rows x 70 columns]

# %%
merged_dropped_df = merged_df.dropna(axis=0)
merged_dropped_df = merged_dropped_df[merged_dropped_df['country'].str.contains('USA')]
merged_dropped_df
# Out:
#       imdb_title_id                               title  \
# 1048      tt0021749                    Luci della città
# 2454      tt0027977                       Tempi moderni
# 2827      tt0029583           Biancaneve e i sette nani
# 3266      tt0031381                       Via col vento
# 3348      tt0031679           Mr. Smith va a Washington
# ...             ...                                 ...
# 85176     tt9134216            Non si scherza col fuoco
# 85221     tt9173418  The Boy - La maledizione di Brahms
# 85266     tt9208444       Impractical Jokers: The Movie
# 85397     tt9354944                                Jexi
# 85740     tt9779516                 Cosa mi lasci di te
#
#                         original_title  year date_published  \
# 1048                       City Lights  1931     1931-04-02
# 2454                      Modern Times  1936     1937-03-12
# 2827   Snow White and the Seven Dwarfs  1937     1938-11-30
# 3266                Gone with the Wind  1939     1949-03-12
# 3348      Mr. Smith Goes to Washington  1939     1947-04-05
# ...                                ...   ...            ...
# 85176                Playing with Fire  2019     2020-02-27
# 85221               Brahms: The Boy II  2020     2020-03-19
# 85266    Impractical Jokers: The Movie  2020     2020-02-28
# 85397                             Jexi  2019     2019-10-11
# 85740                  I Still Believe  2020     2020-03-19
#
#                             genre  duration                        country  \
# 1048       Comedy, Drama, Romance        87                            USA
# 2454        Comedy, Drama, Family        87                            USA
# 2827   Animation, Family, Fantasy        83                            USA
# 3266      Drama, History, Romance       238                            USA
# 3348                Comedy, Drama       129                            USA
# ...                           ...       ...                            ...
# 85176              Comedy, Family        96                            USA
# 85221      Drama, Horror, Mystery        86  USA, China, Canada, Australia
# 85266                      Comedy        92                            USA
# 85397             Comedy, Romance        84                    USA, Canada
# 85740     Biography, Drama, Music       116                            USA
#
#                language                      director  ...  \
# 1048            English               Charles Chaplin  ...
# 2454            English               Charles Chaplin  ...
# 2827            English  William Cottrell, David Hand  ...
# 3266            English  Victor Fleming, George Cukor  ...
# 3348            English                   Frank Capra  ...
# ...                 ...                           ...  ...
# 85176  English, Spanish                  Andy Fickman  ...
# 85221           English            William Brent Bell  ...
# 85266           English                  Chris Henchy  ...
# 85397           English        Jon Lucas, Scott Moore  ...
# 85740           English       Andrew Erwin, Jon Erwin  ...
#
#       females_30age_avg_vote females_30age_votes females_45age_avg_vote  \
# 1048                     8.5              8282.0                    8.4
# 2454                     8.5             10739.0                    8.4
# 2827                     7.6             21144.0                    8.0
# 3266                     8.5             38520.0                    8.6
# 3348                     8.1              6016.0                    8.3
# ...                      ...                 ...                    ...
# 85176                    5.1               485.0                    5.3
# 85221                    4.7               628.0                    5.2
# 85266                    6.7               131.0                    6.0
# 85397                    5.9               835.0                    6.2
# 85740                    6.6               513.0                    7.4
#
#       females_45age_votes  top1000_voters_rating  top1000_voters_votes  \
# 1048               3306.0                    8.1                 645.0
# 2454               3576.0                    8.2                 647.0
# 2827               3813.0                    7.8                 712.0
# 3266              13587.0                    8.0                 732.0
# 3348               3779.0                    8.0                 610.0
# ...                   ...                    ...                   ...
# 85176               207.0                    4.0                 121.0
# 85221               162.0                    3.8                 112.0
# 85266                51.0                    4.7                  62.0
# 85397               230.0                    5.1                 130.0
# 85740               202.0                    4.8                  63.0
#
#       us_voters_rating us_voters_votes non_us_voters_rating  \
# 1048               8.5         27231.0                  8.5
# 2454               8.5         29080.0                  8.5
# 2827               7.7         38861.0                  7.5
# 3266               8.2         65578.0                  8.1
# 3348               8.3         35105.0                  8.0
# ...                ...             ...                  ...
# 85176              5.0          1476.0                  4.8
# 85221              4.5          1128.0                  4.6
# 85266              6.2          1213.0                  5.4
# 85397              6.0          1985.0                  5.9
# 85740              6.8          1089.0                  6.1
#
#        non_us_voters_votes
# 1048               72716.0
# 2454               97123.0
# 2827               72709.0
# 3266              112298.0
# 3348               33596.0
# ...                    ...
# 85176               2979.0
# 85221               3353.0
# 85266                888.0
# 85397               5945.0
# 85740               1679.0
#
# [4246 rows x 70 columns]

# %%
randomized_merged_dropped_df = merged_dropped_df.sample(n=10000, replace=True).reset_index(drop=True)
randomized_merged_dropped_df.head()
# Out:
#   imdb_title_id                        title    original_title  year  \
# 0     tt0343135  ...E alla fine arriva Polly  Along Came Polly  2004
# 1     tt2180411               Into the Woods    Into the Woods  2014
# 2     tt2304933               La quinta onda      The 5th Wave  2016
# 3     tt1430132      Wolverine - L'immortale     The Wolverine  2013
# 4     tt1915581                   Magic Mike        Magic Mike  2012
#
#   date_published                      genre  duration  country  \
# 0     2004-03-12            Comedy, Romance        90      USA
# 1     2015-04-02   Adventure, Comedy, Drama       125      USA
# 2     2016-02-04  Action, Adventure, Sci-Fi       112  USA, UK
# 3     2013-07-25  Action, Adventure, Sci-Fi       126  USA, UK
# 4     2012-09-21              Comedy, Drama       110      USA
#
#             language           director  ... females_30age_avg_vote  \
# 0   English, Spanish       John Hamburg  ...                    5.8
# 1            English       Rob Marshall  ...                    6.0
# 2            English         J Blakeson  ...                    5.5
# 3  English, Japanese      James Mangold  ...                    6.6
# 4            English  Steven Soderbergh  ...                    6.0
#
#   females_30age_votes females_45age_avg_vote females_45age_votes  \
# 0             15884.0                    5.9              2657.0
# 1             16907.0                    6.3              3674.0
# 2              6609.0                    5.7              1536.0
# 3             20757.0                    6.9              4211.0
# 4             22424.0                    6.1              4530.0
#
#    top1000_voters_rating  top1000_voters_votes us_voters_rating  \
# 0                    5.6                 518.0              5.9
# 1                    5.5                 490.0              6.3
# 2                    4.8                 411.0              5.3
# 3                    6.5                 697.0              6.8
# 4                    5.4                 474.0              6.1
#
#   us_voters_votes non_us_voters_rating  non_us_voters_votes
# 0         26267.0                  5.9              61434.0
# 1         21496.0                  5.8              49608.0
# 2          9497.0                  5.1              40802.0
# 3         51630.0                  6.6             179707.0
# 4         22304.0                  6.0              58312.0
#
# [5 rows x 70 columns]

# %%
randomized_merged_dropped_df.to_csv('Sample/sample.csv')

# %%
# The path to our CSV file
file = "Sample/sample.csv"

# Read our Kickstarter data into pandas
sample_df = pd.read_csv(file)
sample_df.head()
# Out:
#    Unnamed: 0 imdb_title_id                        title    original_title  \
# 0           0     tt0343135  ...E alla fine arriva Polly  Along Came Polly
# 1           1     tt2180411               Into the Woods    Into the Woods
# 2           2     tt2304933               La quinta onda      The 5th Wave
# 3           3     tt1430132      Wolverine - L'immortale     The Wolverine
# 4           4     tt1915581                   Magic Mike        Magic Mike
#
#    year date_published                      genre  duration  country  \
# 0  2004     2004-03-12            Comedy, Romance        90      USA
# 1  2014     2015-04-02   Adventure, Comedy, Drama       125      USA
# 2  2016     2016-02-04  Action, Adventure, Sci-Fi       112  USA, UK
# 3  2013     2013-07-25  Action, Adventure, Sci-Fi       126  USA, UK
# 4  2012     2012-09-21              Comedy, Drama       110      USA
#
#             language  ... females_30age_avg_vote females_30age_votes  \
# 0   English, Spanish  ...                    5.8             15884.0
# 1            English  ...                    6.0             16907.0
# 2            English  ...                    5.5              6609.0
# 3  English, Japanese  ...                    6.6             20757.0
# 4            English  ...                    6.0             22424.0
#
#   females_45age_avg_vote females_45age_votes top1000_voters_rating  \
# 0                    5.9              2657.0                   5.6
# 1                    6.3              3674.0                   5.5
# 2                    5.7              1536.0                   4.8
# 3                    6.9              4211.0                   6.5
# 4                    6.1              4530.0                   5.4
#
#    top1000_voters_votes  us_voters_rating us_voters_votes  \
# 0                 518.0               5.9         26267.0
# 1                 490.0               6.3         21496.0
# 2                 411.0               5.3          9497.0
# 3                 697.0               6.8         51630.0
# 4                 474.0               6.1         22304.0
#
#   non_us_voters_rating non_us_voters_votes
# 0                  5.9             61434.0
# 1                  5.8             49608.0
# 2                  5.1             40802.0
# 3                  6.6            179707.0
# 4                  6.0             58312.0
#
# [5 rows x 71 columns]

# %%
sample_df.columns
# Out:
# Index(['Unnamed: 0', 'imdb_title_id', 'title', 'original_title', 'year',
#        'date_published', 'genre', 'duration', 'country', 'language',
#        'director', 'writer', 'production_company', 'actors', 'description',
#        'avg_vote', 'votes', 'budget', 'usa_gross_income',
#        'worlwide_gross_income', 'metascore', 'reviews_from_users',
#        'reviews_from_critics', 'weighted_average_vote', 'total_votes',
#        'mean_vote', 'median_vote', 'votes_10', 'votes_9', 'votes_8', 'votes_7',
#        'votes_6', 'votes_5', 'votes_4', 'votes_3', 'votes_2', 'votes_1',
#        'allgenders_0age_avg_vote', 'allgenders_0age_votes',
#        'allgenders_18age_avg_vote', 'allgenders_18age_votes',
#        'allgenders_30age_avg_vote', 'allgenders_30age_votes',
#        'allgenders_45age_avg_vote', 'allgenders_45age_votes',
#        'males_allages_avg_vote', 'males_allages_votes', 'males_0age_avg_vote',
#        'males_0age_votes', 'males_18age_avg_vote', 'males_18age_votes',
#        'males_30age_avg_vote', 'males_30age_votes', 'males_45age_avg_vote',
#        'males_45age_votes', 'females_allages_avg_vote',
#        'females_allages_votes', 'females_0age_avg_vote', 'females_0age_votes',
#        'females_18age_avg_vote', 'females_18age_votes',
#        'females_30age_avg_vote', 'females_30age_votes',
#        'females_45age_avg_vote', 'females_45age_votes',
#        'top1000_voters_rating', 'top1000_voters_votes', 'us_voters_rating',
#        'us_voters_votes', 'non_us_voters_rating', 'non_us_voters_votes'],
#       dtype='object')

# %%
sample_df[['weighted_average_vote','mean_vote','avg_vote']].corr()
# Out:
#                        weighted_average_vote  mean_vote  avg_vote
# weighted_average_vote               1.000000   0.986239  1.000000
# mean_vote                           0.986239   1.000000  0.986239
# avg_vote                            1.000000   0.986239  1.000000

# %%
y=merged_dropped_df['us_voters_rating']
X=merged_dropped_df[['year','duration','weighted_average_vote']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Scaling the X data by using StandardScaler()
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_train_scaled
# Out:
# array([[-0.98939061,  0.91079406,  0.05627395],
#        [-2.91096948, -0.71866737,  0.8469027 ],
#        [ 0.68154754, -0.14047138, -0.8331834 ],
#        ...,
#        [-0.65520298, -0.71866737, -0.8331834 ],
#        [ 1.09928208,  1.69924314,  0.25393113],
#        [-1.74131278, -0.19303465, -2.31561232]])

# %%
# Transforming the test dataset based on the fit from the training dataset
X_test_scaled = scaler.transform(X_test)
X_test_scaled
# Out:
# array([[-1.49067205, -1.19173682, -0.43786903],
#        [ 0.59800064, -0.45585101,  0.05627395],
#        [-0.9058437 ,  0.59541443, -0.04255465],
#        ...,
#        [-0.32101535,  2.01462277,  1.14338848],
#        [-1.65776587, -0.50841429,  1.14338848],
#        [ 0.34735991,  2.27743913,  2.5269888 ]])

# %%
# Create the model

from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
# Fit the model to the training data. 

### BEGIN SOLUTION

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_squared_error, r2_score

# Use our model to make predictions
predicted = model.predict(X_test)

# Score the predictions with mse and r2
mse = mean_squared_error(y_test, predicted)
r2 = r2_score(y_test, predicted)

print(f"mean squared error (MSE): {mse}")
print(f"R-squared (R2): {r2}")
# Out:
# mean squared error (MSE): 0.02995733790395624
# R-squared (R2): 0.9745482265440881

# %%
model.score(X_test, y_test)
# Out:
# 0.9745482265440881

# %%
predicted
# Out:
# array([6.0381012 , 6.51297684, 6.41616945, ..., 7.63728116, 7.70293267,
#        9.08580778])

# %%
predictions=pd.DataFrame({'y':y_test, 'Predictions':predicted})
predictions
# Out:
#          y  Predictions
# 22551  6.2     6.038101
# 60418  6.4     6.512977
# 27148  6.7     6.416169
# 76336  6.9     7.006358
# 31188  6.4     6.546677
# ...    ...          ...
# 31214  6.9     7.065931
# 31238  7.7     7.666022
# 34998  7.7     7.637281
# 21310  7.8     7.702933
# 48078  9.1     9.085808
#
# [1062 rows x 2 columns]

# %%
predictions[predictions['Predictions']>5]
# Out:
#          y  Predictions
# 22551  6.2     6.038101
# 60418  6.4     6.512977
# 27148  6.7     6.416169
# 76336  6.9     7.006358
# 31188  6.4     6.546677
# ...    ...          ...
# 31214  6.9     7.065931
# 31238  7.7     7.666022
# 34998  7.7     7.637281
# 21310  7.8     7.702933
# 48078  9.1     9.085808
#
# [985 rows x 2 columns]

# %%
clf = RandomForestRegressor(random_state=1, n_estimators=500).fit(X_train, y_train)
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 0.9955512270877337
# Testing Score: 0.9703150110546641

# %%
new_predicted = clf.predict(X_test)
new_predicted
# Out:
# array([6.0908    , 6.64458333, 6.3552    , ..., 7.4854    , 7.699     ,
#        8.7576    ])

# %%
lr_mse = mean_squared_error(y_test, predicted)
rf_mse = mean_squared_error(y_test, new_predicted)
print(f"linear regression mean squared error (MSE): {lr_mse}")
print(f"random forest mean squared error (MSE): {rf_mse}")
# Out:
# linear regression mean squared error (MSE): 0.02995733790395624
# random forest mean squared error (MSE): 0.03493993241968255
